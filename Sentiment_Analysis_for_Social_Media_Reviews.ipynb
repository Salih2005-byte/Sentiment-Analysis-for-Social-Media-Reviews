# %% [markdown]
# <a href="https://colab.research.google.com/github/Salih2005-byte/Sentiment-Analysis-for-Social-Media-Reviews/blob/main/Sentiment_Analysis_for_Social_Media_Reviews.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Data Collection and Preparation

# %%
import pandas as pd
import numpy as np

# %%
#!unzip "drive/MyDrive/Sentiment-Analysis/archive (1).zip" -d "drive/My Drive/Sentiment Analysis/"

# %%
df = pd.read_csv("drive/My Drive/Sentiment Analysis/twitter_training.csv")
df.head(50)
# Out:
#     2401  Borderlands  Positive  \
# 0   2401  Borderlands  Positive
# 1   2401  Borderlands  Positive
# 2   2401  Borderlands  Positive
# 3   2401  Borderlands  Positive
# 4   2401  Borderlands  Positive
# 5   2402  Borderlands  Positive
# 6   2402  Borderlands  Positive
# 7   2402  Borderlands  Positive
# 8   2402  Borderlands  Positive
# 9   2402  Borderlands  Positive
# 10  2402  Borderlands  Positive
# 11  2403  Borderlands   Neutral
# 12  2403  Borderlands   Neutral
# 13  2403  Borderlands   Neutral
# 14  2403  Borderlands   Neutral
# 15  2403  Borderlands   Neutral
# 16  2403  Borderlands   Neutral
# 17  2404  Borderlands  Positive
# 18  2404  Borderlands  Positive
# 19  2404  Borderlands  Positive
# 20  2404  Borderlands  Positive
# 21  2404  Borderlands  Positive
# 22  2404  Borderlands  Positive
# 23  2405  Borderlands  Negative
# 24  2405  Borderlands  Negative
# 25  2405  Borderlands  Negative
# 26  2405  Borderlands  Negative
# 27  2405  Borderlands  Negative
# ...

# %%
df.columns = ['Tweet ID','Entity','Sentiment','Tweet Text']
df.head()
# Out:
#    Tweet ID       Entity Sentiment  \
# 0      2401  Borderlands  Positive
# 1      2401  Borderlands  Positive
# 2      2401  Borderlands  Positive
# 3      2401  Borderlands  Positive
# 4      2401  Borderlands  Positive
#
#                                           Tweet Text
# 0  I am coming to the borders and I will kill you...
# 1  im getting on borderlands and i will kill you ...
# 2  im coming on borderlands and i will murder you...
# 3  im getting on borderlands 2 and i will murder ...
# 4  im getting into borderlands and i can murder y...

# %%
df.shape
# Out:
# (74681, 4)

# %%
df = df.sample(n=40000, random_state=42)
df = df.reset_index(drop=True)
df
# Out:
#        Tweet ID                  Entity   Sentiment  \
# 0          6792                Fortnite  Irrelevant
# 1          4115                   CS-GO    Positive
# 2          5665               HomeDepot    Negative
# 3          9369               Overwatch  Irrelevant
# 4          2476             Borderlands    Positive
# ...         ...                     ...         ...
# 39995     10577  RedDeadRedemption(RDR)    Negative
# 39996      1170          AssassinsCreed    Positive
# 39997      1459             Battlefield    Positive
# 39998     10625  RedDeadRedemption(RDR)    Positive
# 39999      5921               HomeDepot  Irrelevant
#
#                                               Tweet Text
# 0      went to go in george's room to find his door w...
# 1             Yo this looks LIT! Team:GO/Overwatch combo
# 2      Pay attention executive administrators. While ...
# 3      Guy looked at me and says my name was put on t...
# ...

# %%
df.dtypes
# Out:
# Tweet ID       int64
# Entity        object
# Sentiment     object
# Tweet Text    object
# dtype: object

# %%
df.value_counts().describe()
# Out:
# count    38896.000000
# mean         1.018280
# std          0.148524
# min          1.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          5.000000
# Name: count, dtype: float64

# %%
# 1. Silinecek satırların indexlerini bul
dropped_indexes = df[df['Sentiment'] == 'Irrelevant'].index

# 2. Bu indexleri sil (inplace=True kalıcı yapar)
df.drop(dropped_indexes, inplace=True)

# %%
df["Sentiment"].value_counts()
# Out:
# Sentiment
# Negative    12032
# Positive    11310
# Neutral      9719
# Name: count, dtype: int64

# %%
df.isna().sum()
# Out:
# Tweet ID        0
# Entity          0
# Sentiment       0
# Tweet Text    328
# dtype: int64

# %%
df.dropna(subset=['Tweet Text'], inplace=True)

# %%
# Did is this duplicate?
df.loc[df.duplicated()]
# Out:
#        Tweet ID                     Entity Sentiment  \
# 1227       6214                       FIFA  Negative
# 1599       5810                  HomeDepot  Positive
# 2200       9241                  Overwatch  Positive
# 3028        443                ApexLegends  Positive
# 3424       5074        GrandTheftAuto(GTA)  Positive
# ...         ...                        ...       ...
# 39845      1789  CallOfDutyBlackopsColdWar  Positive
# 39877      9291                  Overwatch   Neutral
# 39884      6965            johnson&johnson  Negative
# 39950      1482                Battlefield   Neutral
# 39957      1207                Battlefield  Positive
#
#                                               Tweet Text
# 1227                                        so damn sick
# 1599                                   Congratulations!!
# 2200   So... Just hit level 10 in Overwatch. I know I...
# 3028                                                 WOW
# ...

# %%
df.loc[df.duplicated(subset=['Tweet Text'])]
# Out:
#        Tweet ID                Entity Sentiment  \
# 233        6618              Fortnite  Positive
# 254        5857             HomeDepot  Negative
# 304        4432                Google  Negative
# 698        2956                 Dota2  Positive
# 757       11450  TomClancysRainbowSix   Neutral
# ...         ...                   ...       ...
# 39884      6965       johnson&johnson  Negative
# 39914       321                Amazon   Neutral
# 39950      1482           Battlefield   Neutral
# 39957      1207           Battlefield  Positive
# 39974      5556           Hearthstone   Neutral
#
#                                               Tweet Text
# 233    At the same time, despite the fact that there ...
# 254                                                  The
# 304    It is not the first time that the EU Commissio...
# 698                                                   in
# 757                                Check out my video!
# ...

# %%
# Only delete true duplicates
df = df.drop_duplicates()

# %%
df
# Out:
#        Tweet ID                  Entity Sentiment  \
# 1          4115                   CS-GO  Positive
# 2          5665               HomeDepot  Negative
# 4          2476             Borderlands  Positive
# 5         11558    TomClancysRainbowSix  Negative
# 10         1377             Battlefield  Positive
# ...         ...                     ...       ...
# 39993      4561                  Google  Positive
# 39994      5741               HomeDepot  Negative
# 39995     10577  RedDeadRedemption(RDR)  Negative
# 39997      1459             Battlefield  Positive
# 39998     10625  RedDeadRedemption(RDR)  Positive
#
#                                               Tweet Text
# 1             Yo this looks LIT! Team:GO/Overwatch combo
# 2      Pay attention executive administrators. While ...
# 4                                                    one
# 5           @Rainbow6Game Server are Available in Xbox 🥺
# 10     so Awesome siege attempt... strangest bleeding...
# ...

# %%
from sklearn.utils import resample

# Get the counts of each sentiment
sentiment_counts = df['Sentiment'].value_counts()

# Find the minority class count (Neutral in this case)
min_count = sentiment_counts['Neutral']

# Separate majority and minority classes
df_negative = df[df['Sentiment'] == 'Negative']
df_positive = df[df['Sentiment'] == 'Positive']
df_neutral = df[df['Sentiment'] == 'Neutral']

# Undersample the majority classes
df_negative_undersampled = resample(df_negative,
                                    replace=False,    # sample without replacement
                                    n_samples=min_count, # to match minority class
                                    random_state=42)  # reproducible results

df_positive_undersampled = resample(df_positive,
                                    replace=False,    # sample without replacement
                                    n_samples=min_count, # to match minority class
                                    random_state=42)  # reproducible results

# Combine minority class with undersampled majority classes
df_balanced = pd.concat([df_negative_undersampled, df_positive_undersampled, df_neutral])

# Display new class counts
print("Original sentiment counts:")
print(sentiment_counts)
print("\nBalanced sentiment counts:")
print(df_balanced['Sentiment'].value_counts())

# Update the main DataFrame to the balanced one
df = df_balanced.reset_index(drop=True)
# Out:
# Original sentiment counts:
# Sentiment
# Negative    11745
# Positive    10893
# Neutral      9493
# Name: count, dtype: int64
#
# Balanced sentiment counts:
# Sentiment
# Negative    9493
# Positive    9493
# Neutral     9493
# Name: count, dtype: int64

# %%
df = df.reset_index(drop=True)
df.index = df.index + 1
df
# Out:
#        Tweet ID                  Entity Sentiment  \
# 1         11294    TomClancysRainbowSix  Negative
# 2          8204               Microsoft  Negative
# 3          9566               Overwatch  Negative
# 4          2332              CallOfDuty  Negative
# 5         10951    TomClancysGhostRecon  Negative
# ...         ...                     ...       ...
# 28475      6939         johnson&johnson   Neutral
# 28476        34                  Amazon   Neutral
# 28477       615             ApexLegends   Neutral
# 28478      4550                  Google   Neutral
# 28479     10788  RedDeadRedemption(RDR)   Neutral
#
#                                               Tweet Text
# 1                                          Well... crap.
# 2      Just stumbled across Microsoft Rewards - it se...
# 3      SOMEONE PLEASE RELEASE A BOOK LIST, OVERWATCH ...
# 4      Nice I know you guys aren't taking shit about ...
# 5      @ AskPS _ UK @ UbisoftSupport @ GhostRecon _ U...
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
df["Sentiment"].value_counts().plot(kind="bar", color=["salmon", "lightblue"]);

# %% [markdown]
# ### Preprocessing

# %%
import re
import string
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

# Download NLTK data (if not already downloaded)
nltk.download('stopwords', quiet=True)
nltk.download('wordnet', quiet=True)
nltk.download('punkt', quiet=True)
nltk.download('punkt_tab', quiet=True)

# Initialize lemmatizer and stopwords
lemmatizer = WordNetLemmatizer()
stop_words = set(stopwords.words('english'))

# Extract the key words for sentiment from the stopwords list
stop_words = stop_words - {'no', 'not', 'nothing', 'nor', 'never', 'neither', 'nobody', 'none', 'nowhere'}

def preprocess_text(text):
    if not isinstance(text, str):
        return ""
    # 1. Lowercasing
    text = text.lower()
    # 2. Remove punctuation
    text = re.sub(r'[%s]' % re.escape(string.punctuation), '', text)
    # 3. Remove numbers
    text = re.sub(r'\d+', '', text)
    # 4. Tokenization
    tokens = nltk.word_tokenize(text)
    # 5. Remove stop words and Lemmatize
    processed_tokens = [
        lemmatizer.lemmatize(word) for word in tokens if word not in stop_words and word.isalpha()
    ]
    # 6. Join tokens back into a string
    return " ".join(processed_tokens)

# %%
df['Tweet Text'] = df['Tweet Text'].apply(preprocess_text)
df[['Tweet ID', 'Entity', 'Sentiment', 'Tweet Text']].head()
# Out:
#    Tweet ID                Entity Sentiment  \
# 1     11294  TomClancysRainbowSix  Negative
# 2      8204             Microsoft  Negative
# 3      9566             Overwatch  Negative
# 4      2332            CallOfDuty  Negative
# 5     10951  TomClancysGhostRecon  Negative
#
#                                           Tweet Text
# 1                                          well crap
# 2  stumbled across microsoft reward seems faintly...
# 3  someone please release book list overwatch dog...
# 4  nice know guy arent taking shit hacker game ge...
# 5  askps uk ubisoftsupport ghostrecon uk keep get...

# %%
df["Sentiment"].value_counts()
# Out:
# Sentiment
# Negative    9493
# Positive    9493
# Neutral     9493
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (28479, 4)

# %% [markdown]
# ### Feature Extraction

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
texts = df["Tweet Text"]
vectorizer = TfidfVectorizer(ngram_range=(1,2))
X = vectorizer.fit_transform(texts)

print(vectorizer.get_feature_names_out())
# Out:
# ['aa' 'aa beluba' 'aaa' ... 'فيديو islam' 'فيديو red' 'ℐℓ']

# %%
X
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 563383 stored elements and shape (28479, 169000)>

# %% [markdown]
# ### Modelling

# %%
# Split data into X and y
X

y = df["Sentiment"]

# %%
from sklearn.model_selection import train_test_split
# Split data into train and test sets
np.random.seed(42)

# The train/test split lines are removed to revert the notebook state.
# If you wish to perform the split, please add these lines back:
X_train, X_test, y_train, y_test = train_test_split(X,
                                                    y,
                                                    test_size=0.2)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier

# Put models in a dictionary
models = {"Logistic Regression": LogisticRegression(class_weight='balanced'), # Correct Class Imbalance
          "KNN": KNeighborsClassifier()}

# Create a function to fit and score models
def fit_and_score(models, X_train, X_test, y_train, y_test):
    """
    Fits and evaluates given machine learning models.
    models : a dict of differetn Scikit-Learn machine learning models
    X_train : training data (no labels)
    X_test : testing data (no labels)
    y_train : training labels
    y_test : test labels
    """
    # Set random seed
    np.random.seed(42)
    # Make a dictionary to keep model scores
    model_scores = {}
    # Loop through models
    for name, model in models.items():
        # Fit the model to the data
        model.fit(X_train, y_train)
        # Evaluate the model and append its score to model_scores
        model_scores[name] = model.score(X_test, y_test)
    return model_scores

# %%
model_scores = fit_and_score(models=models,
                             X_train=X_train,
                             X_test=X_test,
                             y_train=y_train,
                             y_test=y_test)

model_scores
# Out:
# {'Logistic Regression': 0.811622191011236, 'KNN': 0.538623595505618}

# %%
from sklearn.model_selection import cross_val_score

for model_name, model_estimator in models.items():
  scores = cross_val_score(
    model_estimator,
    X_train,
    y_train,
    cv=5,
    scoring="accuracy"
  )
  print(f"Cross-validation scores for {model_name}: {scores.mean():.4f} (std: {scores.std():.4f})")
# Out:
# Cross-validation scores for Logistic Regression: 0.7872 (std: 0.0066)
# Cross-validation scores for KNN: 0.5087 (std: 0.0068)

# %%
def predict_sentiment_proba(text, model, vectorizer, preprocess_func):
    # Preprocess the text using the existing function
    preprocessed_text = preprocess_func(text)

    # Vectorize the preprocessed text using the trained vectorizer
    # transformed_text will be a sparse matrix, similar to X
    transformed_text = vectorizer.transform([preprocessed_text])

    # Get probability predictions from the model
    proba = model.predict_proba(transformed_text)[0]

    # Map sentiment classes to probabilities, handling the Turkish labels
    classes = model.classes_ # Get the order of classes from the trained model
    result = {}
    for i, cls in enumerate(classes):
        if cls == 'Negative':
            result['Negative'] = proba[i]
        elif cls == 'Positive':
            result['Positive'] = proba[i]
        elif cls == 'Neutral':
            result['Neutral'] = proba[i]
    return result

# %%
# Select the best performing model (e.g., Logistic Regression)
best_model = models['Logistic Regression']

# Example usage with a new text
example_text_positive = "This movie was fantastic, absolutely loved it!"
sentiment_probabilities_positive = predict_sentiment_proba(example_text_positive, best_model, vectorizer, preprocess_text)
print(f"Sentiment probabilities for '{example_text_positive}':")
print(sentiment_probabilities_positive)

print("\n" + "-"*50 + "\n")

example_text_negative = "Terrible customer service, very disappointed."
sentiment_probabilities_negative = predict_sentiment_proba(example_text_negative, best_model, vectorizer, preprocess_text)
print(f"Sentiment probabilities for '{example_text_negative}':")
print(sentiment_probabilities_negative)

print("\n" + "-"*50 + "\n")

example_text_neutral = "The new update was released today. Nothing much to say."
sentiment_probabilities_neutral = predict_sentiment_proba(example_text_neutral, best_model, vectorizer, preprocess_text)
print(f"Sentiment probabilities for '{example_text_neutral}':")
print(sentiment_probabilities_neutral)
# Out:
# Sentiment probabilities for 'This movie was fantastic, absolutely loved it!':
# {'Negative': np.float64(0.09673947056311362), 'Neutral': np.float64(0.3683590670436947), 'Positive': np.float64(0.5349014623931917)}
#
# --------------------------------------------------
#
# Sentiment probabilities for 'Terrible customer service, very disappointed.':
# {'Negative': np.float64(0.8998590221050774), 'Neutral': np.float64(0.04871034969188633), 'Positive': np.float64(0.051430628203036295)}
#
# --------------------------------------------------
#
# Sentiment probabilities for 'The new update was released today. Nothing much to say.':
# {'Negative': np.float64(0.34358510687697313), 'Neutral': np.float64(0.285529606468802), 'Positive': np.float64(0.37088528665422493)}

# %% [markdown]
# ### Cross Validation

# %%
from sklearn.model_selection import cross_val_score, RandomizedSearchCV
from sklearn.linear_model import LogisticRegression

# Create a hyperparameter grid for LogisticRegression
log_reg_grid = {"C": np.logspace(-4, 4, 20),
                "solver": ["liblinear"]}

# Tune LogisticRegression

np.random.seed(42)

# Setup random hyperparameter search for LogisticRegression
rs_log_reg = RandomizedSearchCV(LogisticRegression(class_weight='balanced'),
                                param_distributions=log_reg_grid,
                                cv=5,
                                n_iter=20,
                                verbose=True)

# Fit random hyperparameter search model for LogisticRegression
rs_log_reg.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# RandomizedSearchCV(cv=5, estimator=LogisticRegression(class_weight='balanced'),
#                    n_iter=20,
#                    param_distributions={'C': array([1.00000000e-04, 2.63665090e-04, 6.95192796e-04, 1.83298071e-03,
#        4.83293024e-03, 1.27427499e-02, 3.35981829e-02, 8.85866790e-02,
#        2.33572147e-01, 6.15848211e-01, 1.62377674e+00, 4.28133240e+00,
#        1.12883789e+01, 2.97635144e+01, 7.84759970e+01, 2.06913808e+02,
#        5.45559478e+02, 1.43844989e+03, 3.79269019e+03, 1.00000000e+04]),
#                                         'solver': ['liblinear']},
#                    verbose=True)

# %%
rs_log_reg.score(X_test, y_test)
# Out:
# 0.8718398876404494

# %% [markdown]
# ### Evalution

# %%
y_test
# Out:
# 12249    Positive
# 24069     Neutral
# 15006    Positive
# 22531     Neutral
# 27988     Neutral
#            ...
# 19872     Neutral
# 5954     Negative
# 2898     Negative
# 24872     Neutral
# 18465    Positive
# Name: Sentiment, Length: 5696, dtype: object

# %%
sentiment_mapping = {'Negative': 0, 'Positive': 1, 'Neutral': 2}
y_test_numerical = y_test.map(sentiment_mapping).to_frame(name='Numerical Sentiment')

print(y_test_numerical)
# Out:
#        Numerical Sentiment
# 12249                    1
# 24069                    2
# 15006                    1
# 22531                    2
# 27988                    2
# ...                    ...
# 19872                    2
# 5954                     0
# 2898                     0
# 24872                    2
# 18465                    1
#
# [5696 rows x 1 columns]

# %%
# Make predictions with tuned model
y_preds = rs_log_reg.predict(X_test)

# %%
y_preds
# Out:
# array(['Positive', 'Positive', 'Negative', ..., 'Negative', 'Neutral',
#        'Positive'], dtype=object)

# %%
y_preds_numerical = pd.Series(y_preds).map(sentiment_mapping).to_frame(name='Numerical Preds Sentiment')

print(y_preds_numerical)
# Out:
#       Numerical Preds Sentiment
# 0                             1
# 1                             1
# 2                             0
# 3                             2
# 4                             2
# ...                         ...
# 5691                          2
# 5692                          0
# 5693                          0
# 5694                          2
# 5695                          1
#
# [5696 rows x 1 columns]

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import ConfusionMatrixDisplay

# Confusion matrix
print(confusion_matrix(y_test, y_preds))
# Out:
# [[1643  104  140]
#  [ 103 1636  176]
#  [ 107  100 1687]]

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import ConfusionMatrixDisplay

class_labels = y_test.unique()

ConfusionMatrixDisplay.from_predictions(
    y_test,
    y_preds,
    display_labels=class_labels,
    cmap=plt.cm.Blues)

plt.title("Confusion Matrix Heatmap")
plt.show()

# %%
print(classification_report(y_test, y_preds))
# Out:
#               precision    recall  f1-score   support
#
#     Negative       0.89      0.87      0.88      1887
#      Neutral       0.89      0.85      0.87      1915
#     Positive       0.84      0.89      0.87      1894
#
#     accuracy                           0.87      5696
#    macro avg       0.87      0.87      0.87      5696
# weighted avg       0.87      0.87      0.87      5696

# %%
y_test.value_counts()
# Out:
# Sentiment
# Neutral     1915
# Positive    1894
# Negative    1887
# Name: count, dtype: int64
